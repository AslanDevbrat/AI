# %%
# Imports and formatting the data
# See previous lab if this is confusing
from matplotlib import pyplot as plt
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import to_categorical
# Imports and formatting the data
# See previous lab if this is confusing
from matplotlib import pyplot as plt
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import to_categorical

num_classes = 10 
image_size = 784

(training_images, training_labels), (test_images, test_labels) = mnist.load_data()
training_data = training_images.reshape(training_images.shape[0], image_size) 
test_data = test_images.reshape(test_images.shape[0], image_size)

training_labels = to_categorical(training_labels, num_classes)
test_labels = to_categorical(test_labels, num_classes)

# A helpful function we'll be using all over the place to plot training information:
def plot_training_history(history, model):
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['training', 'validation'], loc='best')

    plt.show()

    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['training', 'validation'], loc='best')

    plt.show()
    
    loss, accuracy  = model.evaluate(test_data, test_labels, verbose=False)
    print(f'Test loss: {loss:.3}')
    print(f'Test accuracy: {accuracy:.3}')

# %% [markdown]
# ### Part One:
#
# Use Keras to build a network with a single hidden layer and at least 300,000 trainable parameters. Answer the following questions about this model:
#
# * Build a network for classification using the built in MNIST dataset.
# * Use the sigmoid activation function.
# * Use the categorical cross entropy loss function.
# * Use stochastic gradient descent as the optimizer.
# * Train for at least 10 epochs.
# * Plot a chart with your network's performance on training and validation data during training.

# %%
model = Sequential()

model.add(Dense(units=379, activation='sigmoid', input_shape=(image_size,)))
model.add(Dense(units=num_classes, activation='softmax'))
model.summary()

model.compile(optimizer="sgd", loss='categorical_crossentropy', metrics=['accuracy'])
history = model.fit(training_data, training_labels, batch_size=128, epochs=10, verbose=True, validation_split=.1)
plot_training_history(history, model)
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_18 (Dense)             (None, 379)               297515
# _________________________________________________________________
# dense_19 (Dense)             (None, 10)                3800
# ...
# Total params: 301,315
# Trainable params: 301,315
# Non-trainable params: 0
# _________________________________________________________________
# Train on 54000 samples, validate on 6000 samples
# Epoch 1/10
# 54000/54000 [==============================] - 3s 51us/sample - loss: 0.8110 - accuracy: 0.7927 - val_loss: 0.4160 - val_accuracy: 0.8970
# Epoch 2/10
# 54000/54000 [==============================] - 3s 47us/sample - loss: 0.4057 - accuracy: 0.8965 - val_loss: 0.3150 - val_accuracy: 0.9172
# Epoch 3/10
# ...

# %% [markdown]
# * How many total trainable parameters does this model have? **301,315**
#
#   * How many weights? **300926**
#   * How many biases? **389**
# * How accurate was this model on the validation data after 10 epochs? **validation accuracy: 0.9530**
#   * How different was the model's performance on the training data? **Training accuracy: 0.9498**
#   * How different was the model's performance on the test data? **Test Accuracy 0.943  The accuracy is bit low compared to training and validation set**
# * About how long did each epoch take? **~ 3s**

# %% [markdown]
# Use Keras to build a network with a single hidden layer at fewer than 50,000 trainable parameters, then answer the same questions.

# %%
model = Sequential()

model.add(Dense(units=62, activation='sigmoid', input_shape=(image_size,)))
model.add(Dense(units=num_classes, activation='softmax'))
model.summary()

model.compile(optimizer="sgd", loss='categorical_crossentropy', metrics=['accuracy'])
history = model.fit(training_data, training_labels, batch_size=128, epochs=10, verbose=True, validation_split=.1)
plot_training_history(history, model)
# Out:
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_26 (Dense)             (None, 62)                48670
# _________________________________________________________________
# dense_27 (Dense)             (None, 10)                630
# ...
# Total params: 49,300
# Trainable params: 49,300
# Non-trainable params: 0
# _________________________________________________________________
# Train on 54000 samples, validate on 6000 samples
# Epoch 1/10
# 54000/54000 [==============================] - 1s 27us/sample - loss: 1.1846 - accuracy: 0.7021 - val_loss: 0.7002 - val_accuracy: 0.8725
# Epoch 2/10
# 54000/54000 [==============================] - 1s 17us/sample - loss: 0.6469 - accuracy: 0.8581 - val_loss: 0.4959 - val_accuracy: 0.9007
# Epoch 3/10
# ...

# %% [markdown]
# ### Part One:
#
# Use Keras to build a network with a single hidden layer and at least 300,000 trainable parameters. Answer the following questions about this model:
#
# * How many total trainable parameters does this model have?  **49,300**
#   * How many weights? **49228**
#   * How many biases? **72**
# * How accurate was this model on the validation data after 10 epochs?  **Validation accuracy: 0.9380**
#   * How different was the model's performance on the training data? **Training accuracy: 0.9196**
#   * How different was the model's performance on the test data?**Test accuracy: 0.926 **
# * About how long did each epoch take? **~ 1s 17us**

# %% [markdown]
# ### Part Two:
#
# Use Keras to build 3 networks, each with at least 10 hidden layers such that:
#
# * The first model has fewer than 10 nodes per layer.

# %%
model = Sequential()
model.add(Dense(units=9, activation='sigmoid', input_shape=(image_size,)))
model.add(Dense(units=9, activation='sigmoid'))
model.add(Dense(units=9, activation='sigmoid'))
model.add(Dense(units=9, activation='sigmoid'))
model.add(Dense(units=9, activation='sigmoid'))
model.add(Dense(units=9, activation='sigmoid'))
model.add(Dense(units=9, activation='sigmoid'))
model.add(Dense(units=9, activation='sigmoid'))
model.add(Dense(units=9, activation='sigmoid'))
model.add(Dense(units=9, activation='sigmoid'))
model.add(Dense(units=num_classes, activation='softmax'))
model.summary()

model.compile(optimizer="sgd", loss='categorical_crossentropy', metrics=['accuracy'])
history = model.fit(training_data, training_labels, batch_size=128, epochs=10, verbose=True, validation_split=.1)
plot_training_history(history, model)
# Out:
# Model: "sequential_21"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_97 (Dense)             (None, 9)                 7065
# _________________________________________________________________
# dense_98 (Dense)             (None, 9)                 90
# _________________________________________________________________
# dense_99 (Dense)             (None, 9)                 90
# _________________________________________________________________
# dense_100 (Dense)            (None, 9)                 90
# _________________________________________________________________
# dense_101 (Dense)            (None, 9)                 90
# _________________________________________________________________
# dense_102 (Dense)            (None, 9)                 90
# _________________________________________________________________
# dense_103 (Dense)            (None, 9)                 90
# ...

# %% [markdown]
# * The second model has between 10-50 nodes per layer.

# %%
model = Sequential()
model.add(Dense(units=12, activation='sigmoid', input_shape=(image_size,)))
model.add(Dense(units=23, activation='sigmoid'))
model.add(Dense(units=23, activation='sigmoid'))
model.add(Dense(units=45, activation='sigmoid'))
model.add(Dense(units=33, activation='sigmoid'))
model.add(Dense(units=12, activation='sigmoid'))
model.add(Dense(units=32, activation='sigmoid'))
model.add(Dense(units=42, activation='sigmoid'))
model.add(Dense(units=40, activation='sigmoid'))
model.add(Dense(units=29, activation='sigmoid'))
model.add(Dense(units=num_classes, activation='softmax'))
model.summary()

model.compile(optimizer="sgd", loss='categorical_crossentropy', metrics=['accuracy'])
history = model.fit(training_data, training_labels, batch_size=128, epochs=10, verbose=True, validation_split=.1)
plot_training_history(history, model)
# Out:
# Model: "sequential_20"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_86 (Dense)             (None, 12)                9420
# _________________________________________________________________
# dense_87 (Dense)             (None, 23)                299
# _________________________________________________________________
# dense_88 (Dense)             (None, 23)                552
# _________________________________________________________________
# dense_89 (Dense)             (None, 45)                1080
# _________________________________________________________________
# dense_90 (Dense)             (None, 33)                1518
# _________________________________________________________________
# dense_91 (Dense)             (None, 12)                408
# _________________________________________________________________
# dense_92 (Dense)             (None, 32)                416
# ...

# %% [markdown]
# * The third model has between 50-100 nodes per layer.

# %%
model = Sequential()
model.add(Dense(units=67, activation='sigmoid', input_shape=(image_size,)))
model.add(Dense(units=68, activation='sigmoid'))
model.add(Dense(units=96, activation='sigmoid'))
model.add(Dense(units=57, activation='sigmoid'))
model.add(Dense(units=96, activation='sigmoid'))
model.add(Dense(units=87, activation='sigmoid'))
model.add(Dense(units=89, activation='sigmoid'))
model.add(Dense(units=57, activation='sigmoid'))
model.add(Dense(units=98, activation='sigmoid'))
model.add(Dense(units=99, activation='sigmoid'))
model.add(Dense(units=num_classes, activation='softmax'))
model.summary()

model.compile(optimizer="sgd", loss='categorical_crossentropy', metrics=['accuracy'])
history = model.fit(training_data, training_labels, batch_size=128, epochs=10, verbose=True, validation_split=.1)
plot_training_history(history, model)
# Out:
# Model: "sequential_18"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_71 (Dense)             (None, 67)                52595
# _________________________________________________________________
# dense_72 (Dense)             (None, 68)                4624
# _________________________________________________________________
# dense_73 (Dense)             (None, 96)                6624
# _________________________________________________________________
# dense_74 (Dense)             (None, 57)                5529
# _________________________________________________________________
# dense_75 (Dense)             (None, 96)                5568
# _________________________________________________________________
# dense_76 (Dense)             (None, 87)                8439
# _________________________________________________________________
# ...

# %% [markdown]
# * Did any of these models achieve better than 20% accuracy on validation or test data? **NO**
#   * State a hypothesis about why these networks performed the way they did. **Vanishing Gradient is the major reason. As the depth of the neural network increases with relu activation function the gradient become smaller and smaller (tending to zero) and during the back propogation that the weight of the node hardly change. In simple word i can say the model don't learn at all!**
#
# * How many total trainable parameters do each of these models have?
#     **First model:7,975**
#     **Second Model : 18,288**
#     **Third model :112,826**
# * Is there a clear correlation between number of trainable parameters and accuracy? **The accuracy is constant. In the previous part the depth is 1 so no problem related to vanishing gradient also the number of node in those nodes are higher which give higher number of trainable parameters that's why it performed far better than depper networks**

# %% [markdown]
# ### Part Three:
#
# Build a network with at least 3 hidden layers that achieves better than 92% accuracy on validation and test data. You may need to train for more than 10 epochs to achieve this result.

# %%
model = Sequential()
model.add(Dense(units=512, activation='sigmoid', input_shape=(image_size,)))
model.add(Dense(units=256, activation='sigmoid'))
model.add(Dense(units=128, activation='sigmoid'))
model.add(Dense(units=num_classes, activation='softmax'))
model.summary()

model.compile(optimizer="sgd", loss='categorical_crossentropy', metrics=['accuracy'])
history = model.fit(training_data, training_labels, batch_size=128, epochs=20, verbose=True, validation_split=.1)
plot_training_history(history, model)
# Out:
# Model: "sequential_24"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_116 (Dense)            (None, 512)               401920
# _________________________________________________________________
# dense_117 (Dense)            (None, 256)               131328
# _________________________________________________________________
# dense_118 (Dense)            (None, 128)               32896
# _________________________________________________________________
# dense_119 (Dense)            (None, 10)                1290
# ...
# Total params: 567,434
# Trainable params: 567,434
# Non-trainable params: 0
# _________________________________________________________________
# Train on 54000 samples, validate on 6000 samples
# Epoch 1/20
# 54000/54000 [==============================] - 5s 90us/sample - loss: 2.2424 - accuracy: 0.2830 - val_loss: 2.1575 - val_accuracy: 0.4650
# Epoch 2/20
# ...
